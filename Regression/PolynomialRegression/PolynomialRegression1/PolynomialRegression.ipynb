# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <h1 align="center"><font size = 14>PolynomialRegression</font></h1>
# <h4 align="center">September 16-2024<h4>
# <h3 align="center">Armin Amani</h3>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Part1

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 📤 Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 💾 Read CSV file

# %%
df = pd.read_csv('houses.csv')
df
# Out:
#     size(sqft)  bedrooms  floors   age  price
# 0        952.0       2.0     1.0  65.0  271.5
# 1       1244.0       3.0     1.0  64.0  300.0
# 2       1947.0       3.0     2.0  17.0  509.8
# 3       1725.0       3.0     2.0  42.0  394.0
# 4       1959.0       3.0     2.0  15.0  540.0
# ..         ...       ...     ...   ...    ...
# 95      1224.0       2.0     2.0  12.0  329.0
# 96      1432.0       2.0     1.0  43.0  388.0
# 97      1660.0       3.0     2.0  19.0  390.0
# 98      1212.0       3.0     1.0  20.0  356.0
# 99      1050.0       2.0     1.0  65.0  257.8
#
# [100 rows x 5 columns]

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Seperate x and y

# %%
x = df.drop(['floors','bedrooms','price'],axis=1)
x
# Out:
#     size(sqft)   age
# 0        952.0  65.0
# 1       1244.0  64.0
# 2       1947.0  17.0
# 3       1725.0  42.0
# 4       1959.0  15.0
# ..         ...   ...
# 95      1224.0  12.0
# 96      1432.0  43.0
# 97      1660.0  19.0
# 98      1212.0  20.0
# 99      1050.0  65.0
#
# [100 rows x 2 columns]

# %%
y = df[['price']]
y
# Out:
#     price
# 0   271.5
# 1   300.0
# 2   509.8
# 3   394.0
# 4   540.0
# ..    ...
# 95  329.0
# 96  388.0
# 97  390.0
# 98  356.0
# 99  257.8
#
# [100 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Polynomial Features

# %%
poly_model = PolynomialFeatures(degree=3,include_bias=True)
poly_model
# Out:
# PolynomialFeatures(degree=3)

# %%
poly_feature = poly_model.fit_transform(x)
poly_feature
# Out:
# array([[1.00000000e+00, 9.52000000e+02, 6.50000000e+01, 9.06304000e+05,
#         6.18800000e+04, 4.22500000e+03, 8.62801408e+08, 5.89097600e+07,
#         4.02220000e+06, 2.74625000e+05],
#        [1.00000000e+00, 1.24400000e+03, 6.40000000e+01, 1.54753600e+06,
#         7.96160000e+04, 4.09600000e+03, 1.92513478e+09, 9.90423040e+07,
#         5.09542400e+06, 2.62144000e+05],
#        [1.00000000e+00, 1.94700000e+03, 1.70000000e+01, 3.79080900e+06,
#         3.30990000e+04, 2.89000000e+02, 7.38070512e+09, 6.44437530e+07,
#         5.62683000e+05, 4.91300000e+03],
#        [1.00000000e+00, 1.72500000e+03, 4.20000000e+01, 2.97562500e+06,
#         7.24500000e+04, 1.76400000e+03, 5.13295312e+09, 1.24976250e+08,
#         3.04290000e+06, 7.40880000e+04],
#        [1.00000000e+00, 1.95900000e+03, 1.50000000e+01, 3.83768100e+06,
#         2.93850000e+04, 2.25000000e+02, 7.51801708e+09, 5.75652150e+07,
#         4.40775000e+05, 3.37500000e+03],
# ...

# %%
x_poly_df = pd.DataFrame(poly_feature)
x_poly_df.columns = ['1','x1','x2','x1^2','x1x2','x2^2','x1^3','x1^2x2','x2^2x1','x2^3']
x_poly_df
# Out:
#       1      x1    x2       x1^2     x1x2    x2^2          x1^3       x1^2x2  \
# 0   1.0   952.0  65.0   906304.0  61880.0  4225.0  8.628014e+08   58909760.0
# 1   1.0  1244.0  64.0  1547536.0  79616.0  4096.0  1.925135e+09   99042304.0
# 2   1.0  1947.0  17.0  3790809.0  33099.0   289.0  7.380705e+09   64443753.0
# 3   1.0  1725.0  42.0  2975625.0  72450.0  1764.0  5.132953e+09  124976250.0
# 4   1.0  1959.0  15.0  3837681.0  29385.0   225.0  7.518017e+09   57565215.0
# ..  ...     ...   ...        ...      ...     ...           ...          ...
# 95  1.0  1224.0  12.0  1498176.0  14688.0   144.0  1.833767e+09   17978112.0
# 96  1.0  1432.0  43.0  2050624.0  61576.0  1849.0  2.936494e+09   88176832.0
# 97  1.0  1660.0  19.0  2755600.0  31540.0   361.0  4.574296e+09   52356400.0
# 98  1.0  1212.0  20.0  1468944.0  24240.0   400.0  1.780360e+09   29378880.0
# 99  1.0  1050.0  65.0  1102500.0  68250.0  4225.0  1.157625e+09   71662500.0
#
#        x2^2x1      x2^3
# ...

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Part2

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 📤 Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 💾 Read CSV file

# %%
df = pd.read_csv('weatherData.csv')
df
# Out:
#     Pressure (millibars)  Humidity
# 0                1014.40      0.62
# 1                1014.20      0.66
# 2                1014.47      0.79
# 3                1014.45      0.82
# 4                1014.49      0.83
# 5                1014.52      0.85
# 6                1014.16      0.83
# 7                1014.24      0.78
# 8                1014.25      0.72
# 9                1013.96      0.61
# 10               1013.85      0.52
# 11               1013.04      0.46
# 12               1012.22      0.40
# 13               1011.44      0.40
# 14               1010.52      0.37
# 15               1009.83      0.40
# 16               1009.26      0.36
# 17               1008.76      0.43
# 18               1008.36      0.50
# 19               1008.11      0.53
# 20               1008.15      0.55
# 21               1007.85      0.58
# 22               1007.89      0.59
# 23               1007.36      0.60
# 24               1007.26      0.63

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Seperate x and y

# %%
x = df[['Pressure (millibars)']]
x
# Out:
#     Pressure (millibars)
# 0                1014.40
# 1                1014.20
# 2                1014.47
# 3                1014.45
# 4                1014.49
# 5                1014.52
# 6                1014.16
# 7                1014.24
# 8                1014.25
# 9                1013.96
# 10               1013.85
# 11               1013.04
# 12               1012.22
# 13               1011.44
# 14               1010.52
# 15               1009.83
# 16               1009.26
# 17               1008.76
# 18               1008.36
# 19               1008.11
# 20               1008.15
# 21               1007.85
# 22               1007.89
# 23               1007.36
# 24               1007.26

# %%
y = df[['Humidity']]
y
# Out:
#     Humidity
# 0       0.62
# 1       0.66
# 2       0.79
# 3       0.82
# 4       0.83
# 5       0.85
# 6       0.83
# 7       0.78
# 8       0.72
# 9       0.61
# 10      0.52
# 11      0.46
# 12      0.40
# 13      0.40
# 14      0.37
# 15      0.40
# 16      0.36
# 17      0.43
# 18      0.50
# 19      0.53
# 20      0.55
# 21      0.58
# 22      0.59
# 23      0.60
# 24      0.63

# %% [markdown]
# * **the number of dataa is small so we dont seperate the train and test split**

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Polynomial Features

# %%
poly_model = PolynomialFeatures(degree=2,include_bias=True)
poly_model
# Out:
# PolynomialFeatures()

# %%
poly_f = poly_model.fit_transform(x)
poly_f
# Out:
# array([[1.00000000e+00, 1.01440000e+03, 1.02900736e+06],
#        [1.00000000e+00, 1.01420000e+03, 1.02860164e+06],
#        [1.00000000e+00, 1.01447000e+03, 1.02914938e+06],
#        [1.00000000e+00, 1.01445000e+03, 1.02910880e+06],
#        [1.00000000e+00, 1.01449000e+03, 1.02918996e+06],
#        [1.00000000e+00, 1.01452000e+03, 1.02925083e+06],
#        [1.00000000e+00, 1.01416000e+03, 1.02852051e+06],
#        [1.00000000e+00, 1.01424000e+03, 1.02868278e+06],
#        [1.00000000e+00, 1.01425000e+03, 1.02870306e+06],
#        [1.00000000e+00, 1.01396000e+03, 1.02811488e+06],
#        [1.00000000e+00, 1.01385000e+03, 1.02789182e+06],
#        [1.00000000e+00, 1.01304000e+03, 1.02625004e+06],
#        [1.00000000e+00, 1.01222000e+03, 1.02458933e+06],
#        [1.00000000e+00, 1.01144000e+03, 1.02301087e+06],
#        [1.00000000e+00, 1.01052000e+03, 1.02115067e+06],
#        [1.00000000e+00, 1.00983000e+03, 1.01975663e+06],
# ...

# %%
poly_f_df = pd.DataFrame(poly_f)
poly_f_df.columns = ['1','X','X^2']
poly_f_df
# Out:
#       1        X           X^2
# 0   1.0  1014.40  1.029007e+06
# 1   1.0  1014.20  1.028602e+06
# 2   1.0  1014.47  1.029149e+06
# 3   1.0  1014.45  1.029109e+06
# 4   1.0  1014.49  1.029190e+06
# 5   1.0  1014.52  1.029251e+06
# 6   1.0  1014.16  1.028521e+06
# 7   1.0  1014.24  1.028683e+06
# 8   1.0  1014.25  1.028703e+06
# 9   1.0  1013.96  1.028115e+06
# 10  1.0  1013.85  1.027892e+06
# 11  1.0  1013.04  1.026250e+06
# 12  1.0  1012.22  1.024589e+06
# 13  1.0  1011.44  1.023011e+06
# 14  1.0  1010.52  1.021151e+06
# 15  1.0  1009.83  1.019757e+06
# 16  1.0  1009.26  1.018606e+06
# 17  1.0  1008.76  1.017597e+06
# 18  1.0  1008.36  1.016790e+06
# 19  1.0  1008.11  1.016286e+06
# 20  1.0  1008.15  1.016366e+06
# 21  1.0  1007.85  1.015762e+06
# 22  1.0  1007.89  1.015842e+06
# 23  1.0  1007.36  1.014774e+06
# 24  1.0  1007.26  1.014573e+06

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 LR Model

# %%
LR = LinearRegression()
LR
# Out:
# LinearRegression()

# %%
LR.fit(poly_f,y)
# Out:
# LinearRegression()

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Prediction

# %%
y_pred = LR.predict(poly_f)
y_pred
# Out:
# array([[0.75581644],
#        [0.7136288 ],
#        [0.77112186],
#        [0.76672032],
#        [0.77554625],
#        [0.78222566],
#        [0.70546543],
#        [0.72188355],
#        [0.72396152],
#        [0.66601939],
#        [0.64529791],
#        [0.51399416],
#        [0.41924047],
#        [0.36474975],
#        [0.3451439 ],
#        [0.362165  ],
#        [0.39673652],
#        [0.44234113],
#        [0.48910583],
#        [0.5229745 ],
#        [0.51731563],
#        [0.56198476],
#        [0.55573187],
#        [0.64599928],
#        [0.66483005]])

# %%
y
# Out:
#     Humidity
# 0       0.62
# 1       0.66
# 2       0.79
# 3       0.82
# 4       0.83
# 5       0.85
# 6       0.83
# 7       0.78
# 8       0.72
# 9       0.61
# 10      0.52
# 11      0.46
# 12      0.40
# 13      0.40
# 14      0.37
# 15      0.40
# 16      0.36
# 17      0.43
# 18      0.50
# 19      0.53
# 20      0.55
# 21      0.58
# 22      0.59
# 23      0.60
# 24      0.63

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Polynomial plot

# %%
plt.scatter(x,y,color='purple')
plt.plot(x,y_pred,color='k')
plt.title('Polynomial',fontsize=20)
plt.xlabel('Pressure (millibars)',fontsize=13)
plt.ylabel('Humidity',fontsize=13)
plt.show()

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 MAE

# %%
metrics.mean_absolute_error(y,y_pred)
# Out:
# 0.046229254479496745

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Weight & Bias

# %%
print(f"the theta is : {LR.coef_}")
print(f"the theta0 is : {LR.intercept_}")
# Out:
# the theta is : [[ 0.00000000e+00 -5.77225454e+01  2.85583573e-02]]
# the theta0 is : [29167.74604378]

# %% [markdown]
# * **We had three features, so we have three weights and a bias**
